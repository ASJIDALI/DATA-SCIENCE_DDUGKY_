# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('./Car_sales (6).csv')
data.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
data.sample(10)
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 85    Mitsubishi  Montero Sport              39.348               13.880
# 91       Mercury       Villager              20.380               14.795
# 97    Mercedes-B         SLK230               1.526                  NaN
# 98    Mercedes-B      CLK Coupe              11.592                  NaN
# 29      Chrysler  Sebring Conv.              32.775               14.180
# 130       Saturn             SC              24.546               10.590
# 76       Lincoln    Continental              13.798               20.525
# 20     Chevrolet         Malibu             135.126               11.225
# 56          Ford       F-Series             540.561               15.075
# 49          Ford         Taurus             245.815               10.055
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 85           Car              22.527          3.0       173.0      107.3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    object
# ...

# %%
data.rename(columns={'__year_resale_value':'year_resale_value'},inplace=True)

# %% [markdown]
# # histogram

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
data.Sales_in_thousands.plot.hist(figsize=(5,5),cmap='winter_r');

# %% [markdown]
# # boxplot

# %%
data.Sales_in_thousands.plot.box(figsize=(5,5),cmap='turbo_r');

# %%
data.Horsepower.plot.box(figsize=(5,10),cmap='Paired')
# Out:
# <AxesSubplot:>

# %%
data.plot.box(figsize=(22,6),subplots=True);

# %%
data.plot.hist(figsize=(10,30),subplots=True);

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
data.sort_values(by='year_resale_value').plot.line('year_resale_value','Price_in_thousands',figsize=(6,3),cmap='RdGy');

# %%
data.Manufacturer.value_counts().plot.bar(figsize=(12,6),cmap='magma');

# %%
data.sort_values(by='Price_in_thousands')[0:20].plot.bar('Manufacturer','Price_in_thousands',figsize=(5,5),cmap='winter_r')
# Out:
# <AxesSubplot:xlabel='Manufacturer'>

# %%
data.sort_values(by='Price_in_thousands')[:5].plot.barh('Manufacturer','Price_in_thousands',figsize=(10,5))
# Out:
# <AxesSubplot:ylabel='Manufacturer'>

# %%
data.sort_values(by='Price_in_thousands')[:20]
# Out:
#     Manufacturer     Model  Sales_in_thousands  year_resale_value  \
# 26     Chevrolet     Metro              21.855              5.160
# 62       Hyundai    Accent              41.184              5.860
# 129       Saturn        SL              80.620              9.200
# 140       Toyota    Tacoma              84.087              9.575
# 63       Hyundai   Elantra              66.692              7.825
# 55          Ford    Ranger             220.650              7.850
# 46          Ford    Escort              70.227              7.425
# 130       Saturn        SC              24.546             10.590
# 114     Plymouth      Neon              32.734              7.750
# 35         Dodge      Neon              76.034              7.750
# 57         Honda     Civic             199.685              9.850
# 136       Toyota   Corolla             142.535             10.025
# 19     Chevrolet  Cavalier             145.519              9.250
# ...

# %%
data.plot.area('Manufacturer','Price_in_thousands',figsize=(10,5),cmap='plasma')
# Out:
# <AxesSubplot:xlabel='Manufacturer'>

# %%
data.sort_values(by='Horsepower')[0:5].plot.scatter('Latest_Launch','Horsepower',figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Latest_Launch', ylabel='Horsepower'>

# %%
data.plot.box(figsize=(20,15));

# %%
data.Manufacturer.value_counts().plot.pie(figsize=(15,20),autopct='%1.2f%%',legend=True);

# %%
data.plot.kde(figsize=(10,7));

# %%
data.plot.kde(figsize=(10,15),subplots=True);

# %%
data.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
data.plot.hexbin('Curb_weight','Engine_size',gridsize=12,cmap='winter_r')
# Out:
# <AxesSubplot:xlabel='Curb_weight', ylabel='Engine_size'>
